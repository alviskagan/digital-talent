# %% [markdown]
# # MySQL
#
# Sebelum memulai, pastikan sudah :
# - Install Laragon
# - Start All pada Laragon
# - Install PyMySQL dengan cara: conda install pymysql
# - Import database mysqlsampledatabase.sql pada HeidiSQL melalui Tombol Database pada Laragon

# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# ## Berikut adalah Skema Database dari Sample Database yang telah kita Import dengan nama database Classicmodels:
#
# <img src="http://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png" />

# %%
run("SHOW TABLES")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %% [markdown]
# ## 1. Mengambil dan Memilih data dengan SELECT

# %%
run("SELECT * FROM products")
# Out:
#     productCode                                  productName  \
# 0      S10_1678        1969 Harley Davidson Ultimate Chopper
# 1      S10_1949                     1952 Alpine Renault 1300
# 2      S10_2016                        1996 Moto Guzzi 1100i
# 3      S10_4698         2003 Harley-Davidson Eagle Drag Bike
# 4      S10_4757                          1972 Alfa Romeo GTA
# 5      S10_4962                       1962 LanciaA Delta 16V
# 6      S12_1099                            1968 Ford Mustang
# 7      S12_1108                            2001 Ferrari Enzo
# 8      S12_1666                               1958 Setra Bus
# 9      S12_2823                             2002 Suzuki XREO
# 10     S12_3148                           1969 Corvair Monza
# 11     S12_3380                           1968 Dodge Charger
# 12     S12_3891                             1969 Ford Falcon
# 13     S12_3990                      1970 Plymouth Hemi Cuda
# 14     S12_4473                            1957 Chevy Pickup
# 15     S12_4675                           1969 Dodge Charger
# 16     S18_1097                       1940 Ford Pickup Truck
# 17     S18_1129                              1993 Mazda RX-7
# 18     S18_1342                         1937 Lincoln Berline
# 19     S18_1367     1936 Mercedes-Benz 500K Special Roadster
# 20     S18_1589                        1965 Aston Martin DB5
# 21     S18_1662                  1980s Black Hawk Helicopter
# 22     S18_1749                     1917 Grand Touring Sedan
# 23     S18_1889                  1948 Porsche 356-A Roadster
# 24     S18_1984                             1995 Honda Civic
# 25     S18_2238               1998 Chrysler Plymouth Prowler
# 26     S18_2248                           1911 Ford Town Car
# 27     S18_2319                       1964 Mercedes Tour Bus
# 28     S18_2325                    1932 Model A Ford J-Coupe
# 29     S18_2432                        1926 Ford Fire Engine
# ..          ...                                          ...
# 80     S24_4048            1992 Porsche Cayenne Turbo Silver
# 81     S24_4258                        1936 Chrysler Airflow
# 82     S24_4278                      1900s Vintage Tri-Plane
# 83     S24_4620                        1961 Chevrolet Impala
# 84     S32_1268                  1980’s GM Manhattan Express
# 85     S32_1374                             1997 BMW F650 ST
# 86     S32_2206                            1982 Ducati 996 R
# 87     S32_2509                  1954 Greyhound Scenicruiser
# 88     S32_3207       1950's Chicago Surface Lines Streetcar
# 89     S32_3522  1996 Peterbilt 379 Stake Bed with Outrigger
# 90     S32_4289                     1928 Ford Phaeton Deluxe
# 91     S32_4485                    1974 Ducati 350 Mk3 Desmo
# 92     S50_1341                 1930 Buick Marquette Phaeton
# 93     S50_1392             Diamond T620 Semi-Skirted Tanker
# 94     S50_1514               1962 City of Detroit Streetcar
# 95     S50_4713                           2002 Yamaha YZR M1
# 96    S700_1138                        The Schooner Bluenose
# 97    S700_1691                  American Airlines: B767-300
# 98    S700_1938                                The Mayflower
# 99    S700_2047                                   HMS Bounty
# 100   S700_2466               America West Airlines B757-200
# 101   S700_2610                    The USS Constitution Ship
# 102   S700_2824                              1982 Camaro Z28
# 103   S700_2834                                ATA: B757-300
# 104   S700_3167                           F/A 18 Hornet 1/72
# 105   S700_3505                                  The Titanic
# 106   S700_3962                               The Queen Mary
# 107   S700_4002                    American Airlines: MD-11S
# 108    S72_1253                             Boeing X-32A JSF
# 109    S72_3212                                   Pont Yacht
#
#           productLine productScale              productVendor  \
# 0         Motorcycles         1:10            Min Lin Diecast
# 1        Classic Cars         1:10    Classic Metal Creations
# 2         Motorcycles         1:10   Highway 66 Mini Classics
# 3         Motorcycles         1:10          Red Start Diecast
# 4        Classic Cars         1:10    Motor City Art Classics
# 5        Classic Cars         1:10        Second Gear Diecast
# 6        Classic Cars         1:12      Autoart Studio Design
# 7        Classic Cars         1:12        Second Gear Diecast
# 8    Trucks and Buses         1:12  Welly Diecast Productions
# 9         Motorcycles         1:12       Unimax Art Galleries
# 10       Classic Cars         1:18  Welly Diecast Productions
# 11       Classic Cars         1:12  Welly Diecast Productions
# 12       Classic Cars         1:12        Second Gear Diecast
# 13       Classic Cars         1:12        Studio M Art Models
# 14   Trucks and Buses         1:12              Exoto Designs
# 15       Classic Cars         1:12  Welly Diecast Productions
# 16   Trucks and Buses         1:18        Studio M Art Models
# 17       Classic Cars         1:18   Highway 66 Mini Classics
# 18       Vintage Cars         1:18    Motor City Art Classics
# 19       Vintage Cars         1:18        Studio M Art Models
# 20       Classic Cars         1:18    Classic Metal Creations
# 21             Planes         1:18          Red Start Diecast
# 22       Vintage Cars         1:18  Welly Diecast Productions
# 23       Classic Cars         1:18       Gearbox Collectibles
# 24       Classic Cars         1:18            Min Lin Diecast
# 25       Classic Cars         1:18       Gearbox Collectibles
# 26       Vintage Cars         1:18    Motor City Art Classics
# 27   Trucks and Buses         1:18       Unimax Art Galleries
# 28       Vintage Cars         1:18      Autoart Studio Design
# 29   Trucks and Buses         1:18   Carousel DieCast Legends
# ..                ...          ...                        ...
# 80       Classic Cars         1:24              Exoto Designs
# 81       Vintage Cars         1:24        Second Gear Diecast
# 82             Planes         1:24       Unimax Art Galleries
# 83       Classic Cars         1:18    Classic Metal Creations
# 84   Trucks and Buses         1:32    Motor City Art Classics
# 85        Motorcycles         1:32              Exoto Designs
# 86        Motorcycles         1:32       Gearbox Collectibles
# 87   Trucks and Buses         1:32    Classic Metal Creations
# 88             Trains         1:32       Gearbox Collectibles
# 89   Trucks and Buses         1:32          Red Start Diecast
# 90       Vintage Cars         1:32   Highway 66 Mini Classics
# 91        Motorcycles         1:32        Second Gear Diecast
# 92       Vintage Cars         1:50        Studio M Art Models
# 93   Trucks and Buses         1:50   Highway 66 Mini Classics
# 94             Trains         1:50    Classic Metal Creations
# 95        Motorcycles         1:50      Autoart Studio Design
# 96              Ships        1:700      Autoart Studio Design
# 97             Planes        1:700            Min Lin Diecast
# 98              Ships        1:700        Studio M Art Models
# 99              Ships        1:700       Unimax Art Galleries
# 100            Planes        1:700    Motor City Art Classics
# 101             Ships        1:700          Red Start Diecast
# 102      Classic Cars         1:18   Carousel DieCast Legends
# 103            Planes        1:700   Highway 66 Mini Classics
# 104            Planes         1:72    Motor City Art Classics
# 105             Ships        1:700   Carousel DieCast Legends
# 106             Ships        1:700  Welly Diecast Productions
# 107            Planes        1:700        Second Gear Diecast
# 108            Planes         1:72    Motor City Art Classics
# 109             Ships         1:72       Unimax Art Galleries
#
#                                     productDescription  quantityInStock  \
# 0    This replica features working kickstand, front...             7933
# 1    Turnable front wheels; steering function; deta...             7305
# 2    Official Moto Guzzi logos and insignias, saddl...             6625
# 3    Model features, official Harley Davidson logos...             5582
# 4    Features include: Turnable front wheels; steer...             3252
# 5    Features include: Turnable front wheels; steer...             6791
# 6    Hood, doors and trunk all open to reveal highl...               68
# 7    Turnable front wheels; steering function; deta...             3619
# 8    Model features 30 windows, skylights & glare r...             1579
# 9    Official logos and insignias, saddle bags loca...             9997
# 10   1:18 scale die-cast about 10" long doors open,...             6906
# 11   1:12 scale model of a 1968 Dodge Charger. Hood...             9123
# 12   Turnable front wheels; steering function; deta...             1049
# 13   Very detailed 1970 Plymouth Cuda model in 1:12...             5663
# 14   1:12 scale die-cast about 20" long Hood opens,...             6125
# 15   Detailed model of the 1969 Dodge Charger. This...             7323
# 16   This model features soft rubber tires, working...             2613
# 17   This model features, opening hood, opening doo...             3975
# 18   Features opening engine cover, doors, trunk, a...             8693
# 19   This 1:18 scale replica is constructed of heav...             8635
# 20   Die-cast model of the silver 1965 Aston Martin...             9042
# 21   1:18 scale replica of actual Army's UH-60L BLA...             5330
# 22   This 1:18 scale replica of the 1917 Grand Tour...             2724
# 23   This precision die-cast replica features openi...             8826
# 24   This model features, opening hood, opening doo...             9772
# 25   Turnable front wheels; steering function; deta...             4724
# 26   Features opening hood, opening doors, opening ...              540
# 27   Exact replica. 100+ parts. working steering sy...             8258
# 28   This model features grille-mounted chrome horn...             9354
# 29   Gleaming red handsome appearance. Everything i...             2018
# ..                                                 ...              ...
# 80   This replica features opening doors, superb de...             6582
# 81   Features opening trunk,  working steering syst...             4710
# 82   Hand crafted diecast-like metal Triplane is Re...             2756
# 83   This 1:18 scale precision die-cast reproductio...             7869
# 84   This 1980’s era new look Manhattan express is ...             5099
# 85   Features official die-struck logos and baked e...              178
# 86   Features rotating wheels , working kick stand....             9241
# 87   Model features bi-level seating, 50 windows, s...             2874
# 88   This streetcar is a joy to see. It has 80 sepa...             8601
# 89   This model features, opening doors, detailed e...              814
# 90   This model features grille-mounted chrome horn...              136
# 91   This model features two-tone paint with chrome...             3341
# 92    Features opening trunk,  working steering system             7062
# 93   This limited edition model is licensed and per...             1016
# 94   This streetcar is a joy to see. It has 99 sepa...             1645
# 95   Features rotating wheels , working kick stand....              600
# 96   All wood with canvas sails. Measures 31 1/2 in...             1897
# 97   Exact replia with official logos and insignias...             5841
# 98   Measures 31 1/2 inches Long x 25 1/2 inches Hi...              737
# 99   Measures 30 inches Long x 27 1/2 inches High x...             3501
# 100  Official logos and insignias. Working steering...             9653
# 101  All wood with canvas sails. Measures 31 1/2" L...             7083
# 102  Features include opening and closing doors. Co...             6934
# 103  Exact replia with official logos and insignias...             7106
# 104  10" Wingspan with retractable landing gears.Co...              551
# 105  Completed model measures 19 1/2 inches long, 9...             1956
# 106  Exact replica. Wood and Metal. Many extras inc...             5088
# 107  Polished finish. Exact replia with official lo...             8820
# 108  10" Wingspan with retractable landing gears.Co...             4857
# 109  Measures 38 inches Long x 33 3/4 inches High. ...              414
#
#      buyPrice    MSRP
# 0       48.81   95.70
# 1       98.58  214.30
# 2       68.99  118.94
# 3       91.02  193.66
# 4       85.68  136.00
# 5      103.42  147.74
# 6       95.34  194.57
# 7       95.59  207.80
# 8       77.90  136.67
# 9       66.27  150.62
# 10      89.14  151.08
# 11      75.16  117.44
# 12      83.05  173.02
# 13      31.92   79.80
# 14      55.70  118.50
# 15      58.73  115.16
# 16      58.33  116.67
# 17      83.51  141.54
# 18      60.62  102.74
# 19      24.26   53.91
# 20      65.96  124.44
# 21      77.27  157.69
# 22      86.70  170.00
# 23      53.90   77.00
# 24      93.89  142.25
# 25     101.51  163.73
# 26      33.30   60.54
# 27      74.86  122.73
# 28      58.48  127.13
# 29      24.92   60.77
# ..        ...     ...
# 80      69.78  118.28
# 81      57.46   97.39
# 82      36.23   72.45
# 83      32.33   80.84
# 84      53.93   96.31
# 85      66.92   99.89
# 86      24.14   40.23
# 87      25.98   54.11
# 88      26.72   62.14
# 89      33.61   64.64
# 90      33.02   68.79
# 91      56.13  102.05
# 92      27.06   43.64
# 93      68.29  115.75
# 94      37.49   58.58
# 95      34.17   81.36
# 96      34.00   66.67
# 97      51.15   91.34
# 98      43.30   86.61
# 99      39.83   90.52
# 100     68.80   99.72
# 101     33.97   72.28
# 102     46.53  101.15
# 103     59.33  118.65
# 104     54.40   80.00
# 105     51.09  100.17
# 106     53.63   99.31
# 107     36.27   74.03
# 108     32.77   49.66
# 109     33.30   54.60
#
# [110 rows x 9 columns]

# %%
run("SELECT productName,buyPrice FROM products")
# Out:
#                                      productName  buyPrice
# 0          1969 Harley Davidson Ultimate Chopper     48.81
# 1                       1952 Alpine Renault 1300     98.58
# 2                          1996 Moto Guzzi 1100i     68.99
# 3           2003 Harley-Davidson Eagle Drag Bike     91.02
# 4                            1972 Alfa Romeo GTA     85.68
# 5                         1962 LanciaA Delta 16V    103.42
# 6                              1968 Ford Mustang     95.34
# 7                              2001 Ferrari Enzo     95.59
# 8                                 1958 Setra Bus     77.90
# 9                               2002 Suzuki XREO     66.27
# 10                            1969 Corvair Monza     89.14
# 11                            1968 Dodge Charger     75.16
# 12                              1969 Ford Falcon     83.05
# 13                       1970 Plymouth Hemi Cuda     31.92
# 14                             1957 Chevy Pickup     55.70
# 15                            1969 Dodge Charger     58.73
# 16                        1940 Ford Pickup Truck     58.33
# 17                               1993 Mazda RX-7     83.51
# 18                          1937 Lincoln Berline     60.62
# 19      1936 Mercedes-Benz 500K Special Roadster     24.26
# 20                         1965 Aston Martin DB5     65.96
# 21                   1980s Black Hawk Helicopter     77.27
# 22                      1917 Grand Touring Sedan     86.70
# 23                   1948 Porsche 356-A Roadster     53.90
# 24                              1995 Honda Civic     93.89
# 25                1998 Chrysler Plymouth Prowler    101.51
# 26                            1911 Ford Town Car     33.30
# 27                        1964 Mercedes Tour Bus     74.86
# 28                     1932 Model A Ford J-Coupe     58.48
# 29                         1926 Ford Fire Engine     24.92
# ..                                           ...       ...
# 80             1992 Porsche Cayenne Turbo Silver     69.78
# 81                         1936 Chrysler Airflow     57.46
# 82                       1900s Vintage Tri-Plane     36.23
# 83                         1961 Chevrolet Impala     32.33
# 84                   1980’s GM Manhattan Express     53.93
# 85                              1997 BMW F650 ST     66.92
# 86                             1982 Ducati 996 R     24.14
# 87                   1954 Greyhound Scenicruiser     25.98
# 88        1950's Chicago Surface Lines Streetcar     26.72
# 89   1996 Peterbilt 379 Stake Bed with Outrigger     33.61
# 90                      1928 Ford Phaeton Deluxe     33.02
# 91                     1974 Ducati 350 Mk3 Desmo     56.13
# 92                  1930 Buick Marquette Phaeton     27.06
# 93              Diamond T620 Semi-Skirted Tanker     68.29
# 94                1962 City of Detroit Streetcar     37.49
# 95                            2002 Yamaha YZR M1     34.17
# 96                         The Schooner Bluenose     34.00
# 97                   American Airlines: B767-300     51.15
# 98                                 The Mayflower     43.30
# 99                                    HMS Bounty     39.83
# 100               America West Airlines B757-200     68.80
# 101                    The USS Constitution Ship     33.97
# 102                              1982 Camaro Z28     46.53
# 103                                ATA: B757-300     59.33
# 104                           F/A 18 Hornet 1/72     54.40
# 105                                  The Titanic     51.09
# 106                               The Queen Mary     53.63
# 107                    American Airlines: MD-11S     36.27
# 108                             Boeing X-32A JSF     32.77
# 109                                   Pont Yacht     33.30
#
# [110 rows x 2 columns]

# %%
run("SELECT firstName,lastName FROM employees")

# %%
run("SELECT CONCAT(firstName,' ',lastName) AS fullName FROM employees")

# %%
run("SELECT * FROM orders")

# %%
run("SELECT orderNumber,YEAR(orderDate),MONTH(orderDate),DAY(orderDate) FROM orders")

# %%
# DISTINCT : Lihat Perbedaan dari Query dibawah ini
run("SELECT lastName FROM employees")
# run("SELECT DISTINCT lastName FROM employees")

# %% [markdown]
# ## 2. Kondisi dengan WHERE

# %%
run("SELECT productName,buyPrice FROM products WHERE buyPrice>50")

# %%
run("SELECT productName,buyPrice FROM products WHERE buyPrice BETWEEN 50 AND 60")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle='Sales Rep'")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle IN ('Sales Rep','VP Sales')")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle<>'Sales Rep'")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle='Sales Rep' AND officeCode=1")

# %%
run("""
SELECT firstName,lastName,jobTitle,officeCode 
FROM employees 
WHERE jobTitle='Sales Rep' AND officeCode=1 AND lastName='Thompson'
""")

# %%
run("""
SELECT   customername,
         country,
         state,
         creditlimit
FROM customers
WHERE country = 'USA'
        AND state = 'CA'
        AND creditlimit > 100000
""")

# %%
run("SELECT firstName,lastName,jobTitle,officeCode FROM employees WHERE jobTitle<>'Sales Rep' OR officeCode=1")

# %%
run("""
SELECT 
    customername, country
FROM
    customers
WHERE
    country = 'USA' OR country = 'France';
""")

# %% [markdown]
# ## 3. Mengurutkan Hasil dengan Order By

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY buyPrice")
# Out:
#                                     productName       productLine  buyPrice
# 0                       1970 Plymouth Hemi Cuda      Classic Cars     31.92
# 1                         1961 Chevrolet Impala      Classic Cars     32.33
# 2                            1970 Dodge Coronet      Classic Cars     32.37
# 3                              Boeing X-32A JSF            Planes     32.77
# 4                              1957 Vespa GS150       Motorcycles     32.95
# 5                      1928 Ford Phaeton Deluxe      Vintage Cars     33.02
# 6                            1911 Ford Town Car      Vintage Cars     33.30
# 7                                    Pont Yacht             Ships     33.30
# 8   1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses     33.61
# 9                     The USS Constitution Ship             Ships     33.97
# 10                        The Schooner Bluenose             Ships     34.00
# 11                           2002 Yamaha YZR M1       Motorcycles     34.17
# 12                        1957 Ford Thunderbird      Classic Cars     34.21
# 13                       1900s Vintage Bi-Plane            Planes     34.25
# 14                           1934 Ford V8 Coupe      Vintage Cars     34.35
# 15                      1900s Vintage Tri-Plane            Planes     36.23
# 16                    American Airlines: MD-11S            Planes     36.27
# 17                     1960 BSA Gold Star DBD34       Motorcycles     37.32
# 18               1962 City of Detroit Streetcar            Trains     37.49
# 19                    1971 Alpine Renault 1600s      Classic Cars     38.58
# 20                                   HMS Bounty             Ships     39.83
# 21          1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars     43.26
# 22                                The Mayflower             Ships     43.30
# 23                              1982 Camaro Z28      Classic Cars     46.53
# 24             1912 Ford Model T Delivery Wagon      Vintage Cars     46.91
# 25                      1982 Ducati 900 Monster       Motorcycles     47.10
# 26                           1949 Jaguar XK 120      Classic Cars     47.25
# 27                     1940 Ford Delivery Sedan      Vintage Cars     48.64
# 28        1969 Harley Davidson Ultimate Chopper       Motorcycles     48.81
# 29                               P-51-D Mustang            Planes     49.00
# ..                                          ...               ...       ...
# 64             Diamond T620 Semi-Skirted Tanker  Trucks and Buses     68.29
# 65                            1903 Ford Model A      Vintage Cars     68.30
# 66               America West Airlines B757-200            Planes     68.80
# 67                        1996 Moto Guzzi 1100i       Motorcycles     68.99
# 68            1992 Porsche Cayenne Turbo Silver      Classic Cars     69.78
# 69                    1957 Corvette Convertible      Classic Cars     69.93
# 70                       1928 Mercedes-Benz SSK      Vintage Cars     72.56
# 71                            1952 Citroen-15CV      Classic Cars     72.82
# 72                        1976 Ford Gran Torino      Classic Cars     73.49
# 73                       1964 Mercedes Tour Bus  Trucks and Buses     74.86
# 74                           1968 Dodge Charger      Classic Cars     75.16
# 75                  1980s Black Hawk Helicopter            Planes     77.27
# 76                  1992 Ferrari 360 Spider red      Classic Cars     77.90
# 77                               1958 Setra Bus  Trucks and Buses     77.90
# 78                        18th century schooner             Ships     82.34
# 79                             1969 Ford Falcon      Classic Cars     83.05
# 80                              1993 Mazda RX-7      Classic Cars     83.51
# 81                             1940s Ford truck  Trucks and Buses     84.76
# 82                          1972 Alfa Romeo GTA      Classic Cars     85.68
# 83                     1917 Grand Touring Sedan      Vintage Cars     86.70
# 84                           1969 Corvair Monza      Classic Cars     89.14
# 85         2003 Harley-Davidson Eagle Drag Bike       Motorcycles     91.02
# 86                        1970 Triumph Spitfire      Classic Cars     91.92
# 87                             1995 Honda Civic      Classic Cars     93.89
# 88                            1968 Ford Mustang      Classic Cars     95.34
# 89                            2001 Ferrari Enzo      Classic Cars     95.59
# 90                      1956 Porsche 356A Coupe      Classic Cars     98.30
# 91                     1952 Alpine Renault 1300      Classic Cars     98.58
# 92               1998 Chrysler Plymouth Prowler      Classic Cars    101.51
# 93                       1962 LanciaA Delta 16V      Classic Cars    103.42
#
# [94 rows x 3 columns]

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY buyPrice DESC")
# Out:
#                                     productName       productLine  buyPrice
# 0                        1962 LanciaA Delta 16V      Classic Cars    103.42
# 1                1998 Chrysler Plymouth Prowler      Classic Cars    101.51
# 2                      1952 Alpine Renault 1300      Classic Cars     98.58
# 3                       1956 Porsche 356A Coupe      Classic Cars     98.30
# 4                             2001 Ferrari Enzo      Classic Cars     95.59
# 5                             1968 Ford Mustang      Classic Cars     95.34
# 6                              1995 Honda Civic      Classic Cars     93.89
# 7                         1970 Triumph Spitfire      Classic Cars     91.92
# 8          2003 Harley-Davidson Eagle Drag Bike       Motorcycles     91.02
# 9                            1969 Corvair Monza      Classic Cars     89.14
# 10                     1917 Grand Touring Sedan      Vintage Cars     86.70
# 11                          1972 Alfa Romeo GTA      Classic Cars     85.68
# 12                             1940s Ford truck  Trucks and Buses     84.76
# 13                              1993 Mazda RX-7      Classic Cars     83.51
# 14                             1969 Ford Falcon      Classic Cars     83.05
# 15                        18th century schooner             Ships     82.34
# 16                  1992 Ferrari 360 Spider red      Classic Cars     77.90
# 17                               1958 Setra Bus  Trucks and Buses     77.90
# 18                  1980s Black Hawk Helicopter            Planes     77.27
# 19                           1968 Dodge Charger      Classic Cars     75.16
# 20                       1964 Mercedes Tour Bus  Trucks and Buses     74.86
# 21                        1976 Ford Gran Torino      Classic Cars     73.49
# 22                            1952 Citroen-15CV      Classic Cars     72.82
# 23                       1928 Mercedes-Benz SSK      Vintage Cars     72.56
# 24                    1957 Corvette Convertible      Classic Cars     69.93
# 25            1992 Porsche Cayenne Turbo Silver      Classic Cars     69.78
# 26                        1996 Moto Guzzi 1100i       Motorcycles     68.99
# 27               America West Airlines B757-200            Planes     68.80
# 28                            1903 Ford Model A      Vintage Cars     68.30
# 29             Diamond T620 Semi-Skirted Tanker  Trucks and Buses     68.29
# ..                                          ...               ...       ...
# 64                               P-51-D Mustang            Planes     49.00
# 65        1969 Harley Davidson Ultimate Chopper       Motorcycles     48.81
# 66                     1940 Ford Delivery Sedan      Vintage Cars     48.64
# 67                           1949 Jaguar XK 120      Classic Cars     47.25
# 68                      1982 Ducati 900 Monster       Motorcycles     47.10
# 69             1912 Ford Model T Delivery Wagon      Vintage Cars     46.91
# 70                              1982 Camaro Z28      Classic Cars     46.53
# 71                                The Mayflower             Ships     43.30
# 72          1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars     43.26
# 73                                   HMS Bounty             Ships     39.83
# 74                    1971 Alpine Renault 1600s      Classic Cars     38.58
# 75               1962 City of Detroit Streetcar            Trains     37.49
# 76                     1960 BSA Gold Star DBD34       Motorcycles     37.32
# 77                    American Airlines: MD-11S            Planes     36.27
# 78                      1900s Vintage Tri-Plane            Planes     36.23
# 79                           1934 Ford V8 Coupe      Vintage Cars     34.35
# 80                       1900s Vintage Bi-Plane            Planes     34.25
# 81                        1957 Ford Thunderbird      Classic Cars     34.21
# 82                           2002 Yamaha YZR M1       Motorcycles     34.17
# 83                        The Schooner Bluenose             Ships     34.00
# 84                    The USS Constitution Ship             Ships     33.97
# 85  1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses     33.61
# 86                                   Pont Yacht             Ships     33.30
# 87                           1911 Ford Town Car      Vintage Cars     33.30
# 88                     1928 Ford Phaeton Deluxe      Vintage Cars     33.02
# 89                             1957 Vespa GS150       Motorcycles     32.95
# 90                             Boeing X-32A JSF            Planes     32.77
# 91                           1970 Dodge Coronet      Classic Cars     32.37
# 92                        1961 Chevrolet Impala      Classic Cars     32.33
# 93                      1970 Plymouth Hemi Cuda      Classic Cars     31.92
#
# [94 rows x 3 columns]

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice")
# Out:
#                                     productName       productLine  buyPrice
# 0                       1970 Plymouth Hemi Cuda      Classic Cars     31.92
# 1                         1961 Chevrolet Impala      Classic Cars     32.33
# 2                            1970 Dodge Coronet      Classic Cars     32.37
# 3                         1957 Ford Thunderbird      Classic Cars     34.21
# 4                     1971 Alpine Renault 1600s      Classic Cars     38.58
# 5                               1982 Camaro Z28      Classic Cars     46.53
# 6                            1949 Jaguar XK 120      Classic Cars     47.25
# 7                          1969 Dodge Super Bee      Classic Cars     49.05
# 8                    1970 Chevy Chevelle SS 454      Classic Cars     49.24
# 9                     1969 Chevrolet Camaro Z28      Classic Cars     50.51
# 10                  1948 Porsche 356-A Roadster      Classic Cars     53.90
# 11                 1999 Indy 500 Monte Carlo SS      Classic Cars     56.76
# 12                            1985 Toyota Supra      Classic Cars     57.01
# 13                           1969 Dodge Charger      Classic Cars     58.73
# 14                          2002 Chevy Corvette      Classic Cars     62.11
# 15               1948 Porsche Type 356 Roadster      Classic Cars     62.16
# 16                        1965 Aston Martin DB5      Classic Cars     65.96
# 17            1992 Porsche Cayenne Turbo Silver      Classic Cars     69.78
# 18                    1957 Corvette Convertible      Classic Cars     69.93
# 19                            1952 Citroen-15CV      Classic Cars     72.82
# 20                        1976 Ford Gran Torino      Classic Cars     73.49
# 21                           1968 Dodge Charger      Classic Cars     75.16
# 22                  1992 Ferrari 360 Spider red      Classic Cars     77.90
# 23                             1969 Ford Falcon      Classic Cars     83.05
# 24                              1993 Mazda RX-7      Classic Cars     83.51
# 25                          1972 Alfa Romeo GTA      Classic Cars     85.68
# 26                           1969 Corvair Monza      Classic Cars     89.14
# 27                        1970 Triumph Spitfire      Classic Cars     91.92
# 28                             1995 Honda Civic      Classic Cars     93.89
# 29                            1968 Ford Mustang      Classic Cars     95.34
# ..                                          ...               ...       ...
# 64                               The Queen Mary             Ships     53.63
# 65                        18th century schooner             Ships     82.34
# 66               1962 City of Detroit Streetcar            Trains     37.49
# 67                     Collectable Wooden Train            Trains     67.56
# 68  1996 Peterbilt 379 Stake Bed with Outrigger  Trucks and Buses     33.61
# 69                  1980’s GM Manhattan Express  Trucks and Buses     53.93
# 70                            1957 Chevy Pickup  Trucks and Buses     55.70
# 71                       1940 Ford Pickup Truck  Trucks and Buses     58.33
# 72                     1962 Volkswagen Microbus  Trucks and Buses     61.34
# 73             Diamond T620 Semi-Skirted Tanker  Trucks and Buses     68.29
# 74                       1964 Mercedes Tour Bus  Trucks and Buses     74.86
# 75                               1958 Setra Bus  Trucks and Buses     77.90
# 76                             1940s Ford truck  Trucks and Buses     84.76
# 77                     1928 Ford Phaeton Deluxe      Vintage Cars     33.02
# 78                           1911 Ford Town Car      Vintage Cars     33.30
# 79                           1934 Ford V8 Coupe      Vintage Cars     34.35
# 80          1932 Alfa Romeo 8C2300 Spider Sport      Vintage Cars     43.26
# 81             1912 Ford Model T Delivery Wagon      Vintage Cars     46.91
# 82                     1940 Ford Delivery Sedan      Vintage Cars     48.64
# 83                          1904 Buick Runabout      Vintage Cars     52.66
# 84                        1936 Chrysler Airflow      Vintage Cars     57.46
# 85                     1917 Maxwell Touring Car      Vintage Cars     57.54
# 86                    1932 Model A Ford J-Coupe      Vintage Cars     58.48
# 87                         1937 Lincoln Berline      Vintage Cars     60.62
# 88          18th Century Vintage Horse Carriage      Vintage Cars     60.74
# 89                  1913 Ford Model T Speedster      Vintage Cars     60.78
# 90      1941 Chevrolet Special Deluxe Cabriolet      Vintage Cars     64.58
# 91                            1903 Ford Model A      Vintage Cars     68.30
# 92                       1928 Mercedes-Benz SSK      Vintage Cars     72.56
# 93                     1917 Grand Touring Sedan      Vintage Cars     86.70
#
# [94 rows x 3 columns]

# %% [markdown]
# ## 4. Membatasi Hasil Dengan Limit

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice LIMIT 0,10")

# %%
run("SELECT productName,productLine,buyPrice FROM products WHERE buyPrice>30 ORDER BY productLine,buyPrice LIMIT 10,10")

# %% [markdown]
# ## 5. Pencarian String

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstName LIKE 'a%'
""")
# Out:
#    employeeNumber lastName firstName
# 0            1143      Bow   Anthony
# 1            1611   Fixter      Andy

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastName LIKE '%on'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastname LIKE '%on%'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    firstname LIKE 'T_m'
""")

# %%
run("""
SELECT 
    employeeNumber, 
    lastName, 
    firstName
FROM
    employees
WHERE
    lastName NOT LIKE 'B%'
""")

# %%
run("""
SELECT 
    productCode, 
    productName
FROM
    products
WHERE
    productCode LIKE '%\_20%';
""")
# Out:
#   productCode                                productName
# 0    S10_2016                      1996 Moto Guzzi 1100i
# 1    S24_2000                   1960 BSA Gold Star DBD34
# 2    S24_2011                      18th century schooner
# 3    S24_2022  1938 Cadillac V-16 Presidential Limousine
# 4   S700_2047                                 HMS Bounty

# %% [markdown]
# Jika membutuhkan Pencarian yang lebih advanced dapat menggunakan BOOLEAN Text Search atau NATURAL LANGUAGE Search:
# - http://www.mysqltutorial.org/mysql-boolean-text-searches.aspx
# - http://www.mysqltutorial.org/mysql-natural-language-search.aspx

# %% [markdown]
# ## 6. Query Agregasi
# SUM, COUNT, AVG, MIN, MAX + GROUP BY + HAVING

# %%
run("SELECT AVG(buyPrice) AS RataHarga FROM products GROUP BY productline")
# Out:
#    RataHarga
# 0  64.446316
# 1  50.685385
# 2  49.629167
# 3  47.007778
# 4  43.923333
# 5  56.329091
# 6  46.066250

# %%
run("SELECT productLine,AVG(buyPrice) AS RataHarga FROM products GROUP BY productLine")
# Out:
#         productLine  RataHarga
# 0      Classic Cars  64.446316
# 1       Motorcycles  50.685385
# 2            Planes  49.629167
# 3             Ships  47.007778
# 4            Trains  43.923333
# 5  Trucks and Buses  56.329091
# 6      Vintage Cars  46.066250

# %%
# having digunakan untuk memfilter hasil setelah query select dijalankan
run("SELECT productLine,AVG(buyPrice) AS RataHarga FROM products GROUP BY productLine HAVING RataHarga>50")
# Out:
#         productLine  RataHarga
# 0      Classic Cars  64.446316
# 1       Motorcycles  50.685385
# 2  Trucks and Buses  56.329091

# %%
run("SELECT productLine,MIN(buyPrice) AS HargaTermurah FROM products GROUP BY productLine")

# %%
run("SELECT productLine,MAX(buyPrice) AS HargaTermahal FROM products GROUP BY productLine")

# %%
run("SELECT productLine,COUNT(*) AS JumlahProduk FROM products GROUP BY productLine")
# Out:
#         productLine  JumlahProduk
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %%
run("SELECT YEAR(paymentDate) AS Tahun,SUM(amount) AS TotalBayar FROM payments GROUP BY YEAR(paymentDate)")
# Out:
#    Tahun  TotalBayar
# 0   2003  3250217.70
# 1   2004  4313328.25
# 2   2005  1290293.28

# %%
run("""
SELECT 
    YEAR(paymentDate) AS Tahun,
    MONTH(paymentDate) AS Bulan,
    SUM(amount) AS TotalBayar 
FROM payments 
GROUP BY Tahun,Bulan
""")
# Out:
#     Tahun  Bulan  TotalBayar
# 0    2003      1    26267.62
# 1    2003      2   144384.36
# 2    2003      3   199704.48
# 3    2003      4   136313.92
# 4    2003      5   159881.97
# 5    2003      6   180218.98
# 6    2003      7   158247.00
# 7    2003      8   246204.86
# 8    2003      9   161206.23
# 9    2003     10   316857.96
# 10   2003     11   694292.68
# 11   2003     12   826637.64
# 12   2004      1   234152.13
# 13   2004      2   106652.01
# 14   2004      3   404603.21
# 15   2004      4   173245.96
# 16   2004      5   208524.42
# 17   2004      6   185842.86
# 18   2004      7   284191.48
# 19   2004      8   378094.30
# 20   2004      9   476445.53
# 21   2004     10   185103.43
# 22   2004     11   857187.30
# 23   2004     12   819285.62
# 24   2005      1   137468.06
# 25   2005      2   252321.22
# 26   2005      3   385268.09
# 27   2005      4   183897.72
# 28   2005      5   272248.93
# 29   2005      6    59089.26

# %%
ax =run("""
SELECT 
    YEAR(paymentDate) AS Tahun,
    MONTH(paymentDate) AS Bulan,
    SUM(amount) AS TotalBayar 
FROM payments 
WHERE YEAR(paymentDate) < 2005
GROUP BY Tahun,Bulan
HAVING TotalBayar > 300000
ORDER BY TotalBayar DESC
LIMIT 0,10
""")

# %% [markdown]
# ## SELF STUDY
# Materi Digital Talent untuk SQL hanya 3 pertemuan, sehingga hanya cukup untuk menyampaikan SELECT saja, namun kalian belum melihat bagaimana cara untuk membuat Tabel, Kolom, serta Bagaimana melakukan manipulasi Data, berikut materi tambahan untuk dapat memanipulasi data:
#
# - https://www.youtube.com/playlist?list=PLF82-I80PwDN7KSzsJOmd8mwHYe4aAqfF
#
# Playlist dari #1 hingga #10

# %%
# ax = data_tanaman.groupby('nama_provinsi').mean()['produktivitas']
ax = ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun ", figsize=(20, 10), legend=True, fontsize=12)
ax.set_xlabel("Tahun", fontsize=12)
ax.set_ylabel("Jumlah", fontsize=12)
# Out:
# Text(0,0.5,'Jumlah')
